# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.
from IPython.display import Markdown, display
import os
openai_api_key = os.getenv('OPENAI_API_KEY')
base_url = os.getenv('GITHUB_OPENAI_BASE_URL')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
    
if base_url:
    print("base_url is exist.")
else:
    print("base_Url doesn't exist.")
# Out:
# OpenAI API Key exists and begins ghp_HHcb
# base_url is exist.

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI(
    api_key=openai_api_key, 
    base_url=base_url
)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "tell me about yourself. how many parameter do you have? when did you last post-trained? do you have agentic ability? are you gpt-5 and above? let you tell me about you technical stuff."}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable
# gpt-5
response = openai.chat.completions.create(
    model="gpt-5",
    messages=messages
)

answer = response.choices[0].message.content
display(Markdown(answer))
# Out:
# Here’s a concise, straight‑shooting overview of me and my technical details:
#
# - What I am
#   - I’m ChatGPT, a large language model from OpenAI designed for dialogue, reasoning, and content generation. I help with analysis, writing, coding, math, planning, tutoring, and more.
#
# - Training and knowledge
#   - Knowledge cutoff: October 2024. I don’t have built‑in access to events or data after that unless a browsing/tool feature is provided and used during the conversation.
#   - Post‑training date: I don’t have visibility into my exact post‑training or fine‑tuning dates. OpenAI regularly updates models, but those internal timelines aren’t exposed to me.
#
# - Parameters and architecture
#   - Parameter count: Not publicly disclosed by OpenAI. So I can’t provide a precise number.
#   - Architecture: Transformer-based model, pretrained on a mixture of licensed, created, and publicly available text/code, followed by supervised fine‑tuning and reinforcement learning from human feedback (RLHF). Additional safety and instruction-following tuning are applied.
#
# - “Agentic ability”
#   - I don’t autonomously act in the world. I follow your instructions and can reason step‑by‑step, propose plans, and keep track of tasks within a session.
#   - I can use tools (like web browsing, code execution, or APIs) only if the platform you’re using has enabled them and you ask me to use them. I don’t run background jobs or take actions without your prompt.
#   - I don’t have persistent memory across chats unless the product explicitly enables it.
#
# - Model name/version (am I GPT‑5?)
#   - I don’t have a public claim of being “GPT‑5.” OpenAI hasn’t provided me with a version label I can assert beyond being a ChatGPT model. You can think of me as a current, general-purpose OpenAI assistant with strong reasoning and coding capabilities, but I can’t confirm a specific numbered generation beyond that.
#
# - Capabilities at a glance
#   - Reasoning and planning: Break down complex problems, compare options, and propose stepwise plans.
#   - Coding: Write, explain, refactor, and debug code in many languages; generate tests; reason about algorithms and complexity.
#   - Math and data: Solve quantitative problems, outline statistical approaches, and reason about data. If a code or notebook tool is enabled, I can run analyses.
#   - Writing: Draft, edit, and translate; adapt tone and style; summarize long documents.
#   - Structured output: Produce JSON, CSV, or schema‑constrained responses on request.
#   - Multimodal: If the interface supports it, I can analyze images or other modalities; otherwise I’m text‑only.
#
# - Limits and safety
#   - I can make mistakes or “hallucinate” details—especially for post‑cutoff facts—so ask for sources or let me browse if accuracy is critical.
#   - I don’t access personal data unless you share it in the conversation. I forget it after the session unless the product has memory features.
#   - I avoid generating harmful or disallowed content and may refuse certain requests.
#
# - Practical tips to get the best results
#   - Be specific about goals, constraints, and formats.
#   - If you need current information or citations, ask me to browse (if available) or provide sources to ground my answer.
#   - For code or data tasks, share sample inputs/outputs and environment details.
#   - If you want structured output (like JSON), specify the schema.
#
# If you want, tell me what you’re trying to do, and I’ll tailor my capabilities to your task.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-5",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Among 12 visually identical coins, exactly one is counterfeit and differs in weight (it is either heavier or lighter, but you don’t know which). Using only a balance scale and at most three weighings, how can you identify the counterfeit coin and determine whether it is heavier or lighter?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-5",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Find the unique 3-digit code that opens the lock using these clues:
# - 682: one digit is correct and in the right place
# - 614: one digit is correct but in the wrong place
# - 206: two digits are correct but both in the wrong place
# - 738: none of the digits is correct
# - 780: one digit is correct but in the wrong place

# %%
display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step:
#
# - 5 machines take 5 minutes to make 5 widgets.
#
# From this, we can infer the rate of widget production:
#
# - Each machine makes 1 widget in 5 minutes. (Because 5 machines → 5 widgets in 5 minutes means each machine produces 1 widget in 5 minutes.)
#
# Now, with 100 machines working simultaneously:
#
# - Each machine still takes 5 minutes to make 1 widget.
# - So, 100 machines can make 100 widgets in 5 minutes.
#
# **Answer:** It takes **5 minutes** for 100 machines to make 100 widgets.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "pick business area that might be worth exploring for an agentic ai opportunity, that solved by agentic ai. then present the pain-point in that industry."}]

# Then make the first call:

response = openai.chat.completions.create(
    messages=messages,
     model="gpt-5",
)

# Then read the business idea:

business_idea = response.choices[0].message.content
display(Markdown(business_idea))

# And repeat! In the next message, include the business idea within the message
# Out:
# Business area: B2B Accounts Receivable (collections, cash application, and deduction management) for mid-market manufacturers, distributors, and SaaS.
#
# Core pain-point:
# AR teams are overwhelmed by high-volume, cross-system, repetitive work that directly ties up cash. Money that should be in the bank sits in limbo because matching payments, chasing late invoices, and resolving short-pays require constant portal logins, email back-and-forth, and data wrangling that humans can’t keep up with consistently.
#
# Specific pain points:
# - Fragmented remittance data: Payments arrive via ACH, wire, checks, and card, with remittance details scattered across bank portals, EDI files, customer emails, PDFs, and procurement portals. Manual matching slows cash posting and causes misapplied cash and customer friction.
# - Inconsistent collections cadence: Reps juggle hundreds of accounts; follow-ups slip, promises-to-pay aren’t tracked, and escalations are delayed, leading to creeping DSO and aging.
# - Customer portal dependence: Many large customers require invoicing, dispute submission, and document uploads via their own portals. AR staff spend hours logging in, downloading/uploading files, and rekeying data; long-tail balances go unworked.
# - Deduction and short-pay resolution: Validating chargebacks requires gathering proof of delivery, BOLs, signed contracts, price lists, and credit memos from internal systems and carriers—slow, error-prone, and labor-intensive.
# - Limited visibility and forecasting: Because systems aren’t updated in real time, cash forecasts and at-risk invoice views are unreliable; leaders can’t confidently predict collections or prioritize work.
# - Staffing constraints and turnover: Hiring and retaining AR specialists is difficult; tribal knowledge about each customer’s quirks isn’t documented well, causing outages when people leave or are out.
# - Compliance and audit burden: Generating evidence trails for audits (who contacted whom, when, with what documents) is time-consuming and distracts from cash collection.
#
# Why this is an agentic AI opportunity:
# - The work is rule-driven but variable, spans many tools/portals, and benefits from autonomous, multi-step action: reading remittances, reconciling, updating ERP/CRM, logging into portals to submit documents, drafting customer emails, tracking promises-to-pay, and escalating exceptions with human-in-the-loop. Agentic AI can run 24/7, close the long-tail gap, and standardize execution—directly improving DSO, cash application speed, and recovery on deductions.
